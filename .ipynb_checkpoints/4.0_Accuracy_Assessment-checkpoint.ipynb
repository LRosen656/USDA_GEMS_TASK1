# %% [markdown]
# # Accuracy Assessment
#
# This notebook uses the spreadsheets created in "Ground_Truth.ipynb" to find accuracy of each image, index and threshold. First, the overall accuracy from Scikit Learn will be collected from each image and exported to a spreadsheed. Then, a confusion maxrix will be made for each threshold and the overall, precision, and recall accuracy will be collected and exported to spreadsheet.
#
# -Luke Rosen
#
# 5/12/2022
#
# Update 6/1/2022
#
# Appended Precision and Recall Accuracy to local stats (with warnings). Added Index and color values to ground truth data.
#
#
# Update 6/26/2022
#
# Removed 7/8/21 dates.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, precision_score, recall_score  
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from datetime import datetime
import glob

# %%
src = "./Stats/"

# %%
# Image= []

# Plot = []

# Date_Index = []

# Date = []

# Variety = []

# Cover = []

# ac_exg_L = []
# pr_exg_L = []
# rc_exg_L = []


# ac_exgr_L = []
# pr_exgr_L = []
# rc_exgr_L = []


# ac_gli_L = []
# pr_gli_L = []
# rc_gli_L = []

# ac_vari_L = []
# pr_vari_L = []
# rc_vari_L = []


# ac_exg_G = []
# pr_exg_G = []
# rc_exg_G = []

# ac_exgr_G = []
# pr_exgr_G = []
# rc_exgr_G = []

# ac_gli_G = []
# pr_gli_G = []
# rc_gli_G = []

# ac_vari_G = []
# pr_vari_G = []
# rc_vari_G = []


# ac_exg_Z = []
# pr_exg_Z = []
# rc_exg_Z = []

# ac_exgr_Z = []
# pr_exgr_Z = []
# rc_exgr_Z = []

# ac_gli_Z = []
# pr_gli_Z = []
# rc_gli_Z = []

# ac_vari_Z = []
# pr_vari_Z = []
# rc_vari_Z = []

# ac_all = []
# pr_all = []
# rc_all = []

# ac_zero = []
# pr_zero = []
# rc_zero = []

# ac_gz = []
# pr_gz = []
# rc_gz = []

# for stat in glob.glob(src +  "\*.csv"):

#     gt = pd.read_csv(stat)
#     end_path = stat.split("\\")[-1]
#     image = end_path.split(".")[0]     ##Removes the "csv"
#     plot, date = image.split("_")  ## [plot, date]
#     if date != "20210708":
#         Image.append(image)            ##Plot_Date
#         Plot.append(plot)
#         Date_Index.append(date)
#         new_date = datetime.strptime(str(date), "%Y%m%d").strftime("%m/%d/%Y") # yyyymmdd to dd/mm/yyyy
#         Date.append(new_date)
#         if plot.startswith("106") or plot.startswith("203") or plot.startswith("303") or plot.startswith("404"): ##Conditions of variety
#             crop = "Soy"
#             Variety.append(crop)
#         else:
#             crop = "Oat"
#             Variety.append(crop)
#         if plot.startswith("1") and plot.endswith("A") or not plot.startswith("1") and plot.endswith("B"): ##Conditions of cover
#             cover = "Fallow"
#             Cover.append(cover)
#         elif plot.startswith("1") and plot.endswith("C") or plot.startswith("3") and plot.endswith("C") or plot.startswith("2") and plot.endswith("A") or plot.startswith("4") and plot.endswith("A"):
#             cover = "Under"
#             Cover.append(cover)
#         else:
#             cover = "Post"
#             Cover.append(cover)
#         ac_exg_L.append(accuracy_score(gt.Reference, gt.Predicted_EXG_L))     ##EXG_Local
#         pr_exg_L.append(precision_score(gt.Reference, gt.Predicted_EXG_L))
#         rc_exg_L.append(recall_score(gt.Reference, gt.Predicted_EXG_L))

#         ac_exgr_L.append(accuracy_score(gt.Reference, gt.Predicted_EXGR_L))   ##EXGR_Local
#         pr_exgr_L.append(precision_score(gt.Reference, gt.Predicted_EXGR_L)) 
#         rc_exgr_L.append(recall_score(gt.Reference, gt.Predicted_EXGR_L)) 

#         ac_gli_L.append(accuracy_score(gt.Reference, gt.Predicted_GLI_L))     ##GLI_Local
#         pr_gli_L.append(precision_score(gt.Reference, gt.Predicted_GLI_L)) 
#         rc_gli_L.append(recall_score(gt.Reference, gt.Predicted_GLI_L)) 

#         ac_vari_L.append(accuracy_score(gt.Reference, gt.Predicted_VARI_L))   ##VARI_Local
#         pr_vari_L.append(precision_score(gt.Reference, gt.Predicted_VARI_L))
#         rc_vari_L.append(recall_score(gt.Reference, gt.Predicted_VARI_L))

#         ac_exg_G.append(accuracy_score(gt.Reference, gt.Predicted_EXG_G))     ##EXG_Global
#         pr_exg_G.append(precision_score(gt.Reference, gt.Predicted_EXG_G)) 
#         rc_exg_G.append(recall_score(gt.Reference, gt.Predicted_EXG_G)) 

#         ac_exgr_G.append(accuracy_score(gt.Reference, gt.Predicted_EXGR_G))   ##EXGR_Global
#         pr_exgr_G.append(precision_score(gt.Reference, gt.Predicted_EXGR_G)) 
#         rc_exgr_G.append(recall_score(gt.Reference, gt.Predicted_EXGR_G)) 

#         ac_gli_G.append(accuracy_score(gt.Reference, gt.Predicted_GLI_G))     ##GLI_Global
#         pr_gli_G.append(precision_score(gt.Reference, gt.Predicted_GLI_G))
#         rc_gli_G.append(recall_score(gt.Reference, gt.Predicted_GLI_G))               

#         ac_vari_G.append(accuracy_score(gt.Reference, gt.Predicted_VARI_G))   ##VARI_Glboal
#         pr_vari_G.append(precision_score(gt.Reference, gt.Predicted_VARI_G))
#         rc_vari_G.append(recall_score(gt.Reference, gt.Predicted_VARI_G))

#         ac_exg_Z.append(accuracy_score(gt.Reference, gt.Predicted_EXG_Z))     ##EXG_Zero
#         pr_exg_Z.append(precision_score(gt.Reference, gt.Predicted_EXG_Z))
#         rc_exg_Z.append(recall_score(gt.Reference, gt.Predicted_EXG_Z))

#         ac_exgr_Z.append(accuracy_score(gt.Reference, gt.Predicted_EXGR_Z))   ##EXGR_Zero
#         pr_exgr_Z.append(precision_score(gt.Reference, gt.Predicted_EXGR_Z))
#         rc_exgr_Z.append(recall_score(gt.Reference, gt.Predicted_EXGR_Z))

#         ac_gli_Z.append(accuracy_score(gt.Reference, gt.Predicted_GLI_Z))     ##GLI_Zero
#         pr_gli_Z.append(precision_score(gt.Reference, gt.Predicted_GLI_Z))    
#         rc_gli_Z.append(recall_score(gt.Reference, gt.Predicted_GLI_Z))

#         ac_vari_Z.append(accuracy_score(gt.Reference, gt.Predicted_VARI_Z))   ##VARI_Zero
#         pr_vari_Z.append(precision_score(gt.Reference, gt.Predicted_VARI_Z))   
#         rc_vari_Z.append(recall_score(gt.Reference, gt.Predicted_VARI_Z))   

#         ac_all.append(accuracy_score(gt.Reference, gt.Predicted_ALL_MODE))   ##Mode
#         pr_all.append(precision_score(gt.Reference, gt.Predicted_ALL_MODE))   
#         rc_all.append(recall_score(gt.Reference, gt.Predicted_ALL_MODE))  

#         ac_zero.append(accuracy_score(gt.Reference, gt.Predicted_ZERO_MODE))   ##Zero Mode
#         pr_zero.append(precision_score(gt.Reference, gt.Predicted_ZERO_MODE))   
#         rc_zero.append(recall_score(gt.Reference, gt.Predicted_ZERO_MODE))  

#         ac_gz.append(accuracy_score(gt.Reference, gt.Predicted_GLOBAL_ZERO_MODE))   ##Global Zero Mode
#         pr_gz.append(precision_score(gt.Reference, gt.Predicted_GLOBAL_ZERO_MODE))   
#         rc_gz.append(recall_score(gt.Reference, gt.Predicted_GLOBAL_ZERO_MODE))  

# local_df = pd.DataFrame({"Image":Image, "Plot":Plot, "Date_Index":Date_Index, "Date":Date, "Variety":Variety, "Cover":Cover, 
#                          "EXG_Local_AC":ac_exg_L, "EXG_Local_PR":pr_exg_L, "EXG_Local_RC":rc_exg_L, 
#                          "EXGR_Local_AC":ac_exgr_L, "EXGR_Local_PR":pr_exgr_L, "EXGR_Local_RC":rc_exgr_L, 
#                          "GLI_Local_AC":ac_gli_L, "GLI_Local_PR":pr_gli_L, "GLI_Local_RC":rc_gli_L, 
#                          "VARI_Local_AC":ac_vari_L, "VARI_Local_PR":pr_vari_L, "VARI_Local_RC":rc_vari_L,
#                         "EXG_Global_AC":ac_exg_G, "EXG_Global_PR":pr_exg_G, "EXG_Global_RC":rc_exg_G, 
#                          "EXGR_Global_AC":ac_exgr_G, "EXGR_Global_PR":pr_exgr_G, "EXGR_Global_RC":rc_exgr_G,
#                          "GLI_Global_AC":ac_gli_G,  "GLI_Global_PR":pr_gli_G, "GLI_Global_RC":rc_gli_G,
#                          "VARI_Global_AC":ac_vari_G, "VARI_Global_PR":pr_vari_G, "VARI_Global_RC":rc_vari_G,
#                          "EXG_Zero_AC":ac_exg_Z, "EXG_Zero_PR":pr_exg_Z, "EXG_Zero_RC":rc_exg_Z,
#                          "EXGR_Zero_AC":ac_exgr_Z, "EXGR_Zero_PR":pr_exgr_Z, "EXGR_Zero_RC":rc_exgr_Z,
#                          "GLI_Zero_AC":ac_gli_Z, "GLI_Zero_PR":pr_gli_Z, "GLI_Zero_RC":rc_gli_Z,
#                          "VARI_Zero_AC":ac_vari_Z, "VARI_Zero_PR":pr_vari_Z, "VARI_Zero_RC":rc_vari_Z,
#                         "ALL_Mode_AC":ac_all, "ALL_Mode_PR":pr_all, "Mode_RC":rc_all,
#                         "ZERO_Mode_AC":ac_zero, "ZERO_Mode_PR":pr_zero, "ZERO_Mode_RC":rc_zero,
#                         "Global_Zero_Mode_AC":ac_gz, "GLobal_Zero_Mode_PR":pr_gz, "GLobal_Zero_Mode_RC":rc_gz})

# %%
# local_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <module>
# ----> 1 local_df
#
# NameError: name 'local_df' is not defined

# %%
#local_df.to_csv("./Image_Stats.csv", index = False)

# %%
Image = []

X = []

Y = []

Plot = []

Date_Index = []

Date = []

Variety = []

Cover = []

y_true = []

y_pred_exg_L = []

y_pred_exgr_L = []

y_pred_gli_L = []

y_pred_vari_L = []

y_pred_exg_G = []

y_pred_exgr_G = []

y_pred_gli_G = []

y_pred_vari_G = []

y_pred_exg_Z = []

y_pred_exgr_Z = []

y_pred_gli_Z = []

y_pred_vari_Z = []

y_pred_all = []
y_pred_zero = []
y_pred_gz = []

exg_value = []
exgr_value = []
gli_value = []
vari_value = []

red_value = []
green_value = []
blue_value = []

for stat in glob.glob(src + "*.csv"):

    gt = pd.read_csv(stat)
    end_path = stat.split("\\")[-1]
    image = end_path.split(".")[0]


    for index, row in gt.iterrows():
        plot, date = image.split("_")  ## [plot, date]
        if date != "20210708":
            Image.append(image)                 ##Plot_Date
            X.append(row["X"])
            Y.append(row["Y"])
            plot, date = image.split("_")  ## [plot, date]
            Plot.append(plot)
            Date_Index.append(date)
            new_date = datetime.strptime(str(date), "%Y%m%d").strftime("%m/%d/%Y") # yyyymmdd to dd/mm/yyyy
            Date.append(new_date)
            if plot.startswith("106") or plot.startswith("203") or plot.startswith("303") or plot.startswith("404"): ##Conditions of variety
                crop = "Soy"
                Variety.append(crop)
            else:
                crop = "Oat"
                Variety.append(crop)
            if plot.startswith("1") and plot.endswith("A") or not plot.startswith("1") and plot.endswith("B"): ##Conditions of cover
                cover = "Fallow"
                Cover.append(cover)
            elif plot.startswith("1") and plot.endswith("C") or plot.startswith("3") and plot.endswith("C") or plot.startswith("2") and plot.endswith("A") or plot.startswith("4") and plot.endswith("A"):
                cover = "Under"
                Cover.append(cover)
            else:
                cover = "Post"
                Cover.append(cover)
            y_true.append(row["Reference"].astype(int))               ##Reference
            y_pred_exg_L.append(row["Predicted_EXG_L"].astype(int))   ##EXG_Local
            y_pred_exgr_L.append(row["Predicted_EXGR_L"].astype(int)) ##EXGR_Local
            y_pred_gli_L.append(row["Predicted_GLI_L"].astype(int))   ##GLI_Local
            y_pred_vari_L.append(row["Predicted_VARI_L"].astype(int)) ##VARI_Local
            y_pred_exg_G.append(row["Predicted_EXG_G"].astype(int))   ##EXG_Global
            y_pred_exgr_G.append(row["Predicted_EXGR_G"].astype(int)) ##EXGR_Global
            y_pred_gli_G.append(row["Predicted_GLI_G"].astype(int))   ##GLI_Global
            y_pred_vari_G.append(row["Predicted_VARI_G"].astype(int)) ##VARI_Global       
            y_pred_exg_Z.append(row["Predicted_EXG_Z"].astype(int))   ##EXG_Zero
            y_pred_exgr_Z.append(row["Predicted_EXGR_Z"].astype(int)) ##EXGR_Zero
            y_pred_gli_Z.append(row["Predicted_GLI_Z"].astype(int))   ##GLI_Zero
            y_pred_vari_Z.append(row["Predicted_VARI_Z"].astype(int)) ##VARI_Zero
            y_pred_all.append(row["Predicted_ALL_MODE"].astype(int)) ##VARI_Zero
            y_pred_zero.append(row["Predicted_ZERO_MODE"].astype(int)) ##VARI_Zero
            y_pred_gz.append(row["Predicted_GLOBAL_ZERO_MODE"].astype(int)) ##VARI_Zero
            exg_value.append(row["EXG_Value"])
            exgr_value.append(row["EXGR_Value"])
            gli_value.append(row["GLI_Value"])
            vari_value.append(row["VARI_Value"])
            red_value.append(row["Red_Value"])
            green_value.append(row["Green_Value"])
            blue_value.append(row["Blue_Value"])
stats_df = pd.DataFrame({"Image": Image, "Plot":Plot, "X":X, "Y":Y, "Date_Index":Date_Index, "Date":Date, "Variety":Variety, "Cover":Cover,
                         "Reference": y_true, "Predicted_EXG_L":y_pred_exg_L, 
                        "Predicted_EXGR_L":y_pred_exgr_L, "Predicted_GLI_L": y_pred_gli_L, 
                         "Predicted_VARI_L":y_pred_vari_L, "Predicted_EXG_G": y_pred_exg_G, 
                         "Predicted_EXGR_G":y_pred_exgr_G,
                        "Predicted_GLI_G":y_pred_gli_G, "Predicted_VARI_G":y_pred_vari_G,
                        "Predicted_EXG_Z":y_pred_exg_Z, "Predicted_EXGR_Z":y_pred_exgr_Z, "Predicted_GLI_Z":y_pred_gli_Z,
                        "Predicted_VARI_Z":y_pred_vari_Z,
                        "Predicted_ALL_MODE":y_pred_all, "Predicted_ZERO_MODE":y_pred_zero, "Predicted_GLOBAL_ZERO_MODE":y_pred_gz,
                        "EXG_Value":exg_value, "EXGR_Value":exgr_value, "GLI_Value":gli_value, "VARI_Value":vari_value,
                        "Red_Value":red_value, "Green_Value":green_value, "Blue_Value":blue_value})

# %%
stats_df
# Out:
#               Image  Plot       X       Y Date_Index        Date Variety  \
# 0     207A_20210821  207A   170.0  1130.0   20210821  08/21/2021     Oat
# 1     207A_20210821  207A   533.0   773.0   20210821  08/21/2021     Oat
# 2     207A_20210821  207A   926.0  1283.0   20210821  08/21/2021     Oat
# 3     207A_20210821  207A  1024.0    44.0   20210821  08/21/2021     Oat
# 4     207A_20210821  207A   204.0    62.0   20210821  08/21/2021     Oat
# ...             ...   ...     ...     ...        ...         ...     ...
# 1435  103C_20210909  103C  1100.0  1234.0   20210909  09/09/2021     Oat
# 1436  103C_20210909  103C  1049.0   419.0   20210909  09/09/2021     Oat
# 1437  103C_20210909  103C   354.0   168.0   20210909  09/09/2021     Oat
# 1438  103C_20210909  103C   706.0   970.0   20210909  09/09/2021     Oat
# 1439  103C_20210909  103C   180.0   473.0   20210909  09/09/2021     Oat
#
#       Cover  Reference  Predicted_EXG_L  ...  Predicted_ALL_MODE  \
# ...

# %%
stats_df.to_csv("./Ground_Truth.csv", index = False)

# %%
##Empty List for DataFrame 

Thresh = []

Overall = []

Precision = []

Recall = []

TNR = []

# %%
##EXG Local stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_EXG_L)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative




ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Local Thresh Excess Green")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)  

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall, "\n\n"
     "TNR:", tnr)

Thresh.append("EXG_Local")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
TNR.append(tnr)
# Out:
# Overall Accuracy: 0.5236111111111111
#
# Precision: 0.3306188925081433
#
# Recall: 0.4246861924686193
#
# TNR 0.5727650727650727

# %%
##EXGR Local Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_EXGR_L)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Local Thresh Excess Green minus Red")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)


print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("EXGR_Local")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.44583333333333336
#
# Precision: 0.300498753117207
#
# Recall: 0.50418410041841

# %%
##GLI Local Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_GLI_L)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative




ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Local Thresh Green Leaf Index")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("GLI_Local")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.4701388888888889
#
# Precision: 0.3341094295692666
#
# Recall: 0.600418410041841

# %%
##VARI Local Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_VARI_L)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Local Thresh Visible Atmospherically Resistant Index")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)


print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("VARI_Local")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.4986111111111111
#
# Precision: 0.38640595903165736
#
# Recall: 0.8682008368200836

# %%
##EXG Global Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_EXG_G)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Global Thresh Excess Green")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)


print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("EXG_Global")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.8111111111111111
#
# Precision: 0.8301282051282052
#
# Recall: 0.5418410041841004

# %%
##EXGR Global Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_EXGR_G)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative




ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Global Thresh Excess Green minus Red")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("EXGR_Global")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.8375
#
# Precision: 0.8297297297297297
#
# Recall: 0.6422594142259415

# %%
##GLI Global Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_GLI_G)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Global Thresh Green Leaf Index")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("GLI_Global")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.8409722222222222
#
# Precision: 0.7971360381861575
#
# Recall: 0.698744769874477

# %%
##VARI Global Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_VARI_G)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative




ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Global Thresh Visible Atmospherically Resistant Index")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)


print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("VARI_Global")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.5638888888888889
#
# Precision: 0.43106617647058826
#
# Recall: 0.9811715481171548

# %%
##EXG Zero Stats

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_EXG_Z)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative




ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Zero Thresh Excess Green")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)


print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("EXG_Zero")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.5548611111111111
#
# Precision: 0.4265103697024346
#
# Recall: 0.9895397489539749

# %%
##EXGR Zero Stats 

cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_EXGR_Z)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Zero Thresh Excess Green minus Red")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("EXGR_Zero")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.8625
#
# Precision: 0.7405498281786942
#
# Recall: 0.9016736401673641

# %%
cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_GLI_Z)


FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Zero Thresh Green Leaf Index")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("GLI_Zero")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.5548611111111111
#
# Precision: 0.4265103697024346
#
# Recall: 0.9895397489539749

# %%
cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_VARI_Z)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Zero Thresh Visible Atmospherically Resistant Index")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("VARI_Zero")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.79375
#
# Precision: 0.6248275862068966
#
# Recall: 0.9476987447698745

# %%
cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_ALL_MODE)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative


ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Mode")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("Mode")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.7534722222222222
#
# Precision: 0.5845942228335625
#
# Recall: 0.8891213389121339

# %%
cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_ZERO_MODE)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative


ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Zero Mode")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)


print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("Zero_Mode")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.7923611111111111
#
# Precision: 0.6231086657496562
#
# Recall: 0.9476987447698745

# %%
cm =confusion_matrix(stats_df.Reference, stats_df.Predicted_GLOBAL_ZERO_MODE)

FP = cm[0,1]                       ## False Positive
FN = cm[1,0]                       ## False Negative
TP = cm[1,1]                       ## True Positive
TN = cm[0,0]                       ## True Negative



ls= ["Non-Vegetation", "Vegetation"]


disp= ConfusionMatrixDisplay(confusion_matrix = cm, display_labels= ls)



disp.plot()
plt.title("Global Zero Mode")
plt.show()

accuracy = (TP+TN)/(TP+FP+FN+TN)      

precision = TP/(TP+FP)

recall = TP/(TP+FN)

tnr = TN/(TN+FP)

print("Overall Accuracy:", accuracy, "\n\n"
      "Precision:", precision, "\n\n"
      "Recall:", recall)

Thresh.append("Global_Zero_Mode")
Overall.append(accuracy)
Precision.append(precision)
Recall.append(recall)
# Out:
# Overall Accuracy: 0.8625
#
# Precision: 0.7405498281786942
#
# Recall: 0.9016736401673641

# %%
Thresh_stats_df = pd.DataFrame({"Thresh_Index":Thresh, "Overall":Overall, "Precision":Precision, "Recall":Recall, "TNR":TNR})

Thresh_stats_df.to_csv("./Overall_Index_Accuracy.csv", index = False)

# %% [markdown]
# This notebook is complete. The next notebook will summarize vegetation cover.
