# %%
import seaborn as sns
import pandas as pd
import os
import numpy as np
from datetime import datetime , timedelta
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates

# %%
data = pd.read_csv("Image_Stats.csv")
data.to_csv("L:/USDA/Old/Image_Stats_" + str(datetime.today().month) + "_" + str(datetime.today().day) + ".csv")

# %%
data
# Out:
#             Image  Plot  Date_Index        Date Variety   Cover  EXG_Local_AC  \
# 0   302A_20210708  302A    20210708  07/08/2021     Oat    Post      0.333333
# 1   403C_20210708  403C    20210708  07/08/2021     Oat    Post      0.866667
# 2   309C_20210708  309C    20210708  07/08/2021     Oat   Under      0.466667
# 3   207A_20210708  207A    20210708  07/08/2021     Oat   Under      0.200000
# 4   102C_20210708  102C    20210708  07/08/2021     Oat   Under      0.366667
# 5   402C_20210708  402C    20210708  07/08/2021     Oat    Post      0.666667
# 6   206A_20210708  206A    20210708  07/08/2021     Oat   Under      0.466667
# 7   401A_20210708  401A    20210708  07/08/2021     Oat   Under      0.766667
# 8   207A_20210821  207A    20210821  08/21/2021     Oat   Under      0.133333
# 9   301A_20210821  301A    20210821  08/21/2021     Oat    Post      0.833333
# 10  409B_20210821  409B    20210821  08/21/2021     Oat  Fallow      0.866667
# ...

# %%
# Plot = []
# Date = []
# cover_type = []
# for index, row in data.iterrows():
#     plot= row.Image.split("_")[0]
#     Plot.append(plot)
#     date = row.Image.split("_")[1]
#     Date.append(int(date))
#     if plot.startswith("1") and plot.endswith("A") or not plot.startswith("1") and plot.endswith("B"):
#         cover = "Fallow"
#         cover_type.append(cover)
#     elif plot.startswith("1") and plot.endswith("C") or plot.startswith("3") and plot.endswith("C") or plot.startswith("2") and plot.endswith("A") or plot.startswith("4") and plot.endswith("A"):
#         cover = "Under"
#         cover_type.append(cover)
#     else:
#         cover = "Post"
#         cover_type.append(cover)

# %%
data["Datetime"] = pd.to_datetime(data["Date_Index"], format = "%Y%m%d")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Image           56 non-null     object
#  1   Plot            56 non-null     object
#  2   Date_Index      56 non-null     int64
#  3   Date            56 non-null     object
#  4   Variety         56 non-null     object
#  5   Cover           56 non-null     object
#  6   EXG_Local_AC    56 non-null     float64
#  7   EXGR_Local_AC   56 non-null     float64
#  8   GLI_Local_AC    56 non-null     float64
#  9   VARI_Local_AC   56 non-null     float64
#  10  EXG_Global_AC   56 non-null     float64
#  11  EXGR_Global_AC  56 non-null     float64
#  12  GLI_Global_AC   56 non-null     float64
#  13  VARI_Global_AC  56 non-null     float64
#  14  EXG_Zero_AC     56 non-null     float64
#  15  EXGR_Zero_AC    56 non-null     float64
#  16  GLI_Zero_AC     56 non-null     float64
# ...

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Datetime", y = "EXGR_Zero_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = data, palette = ["b", "g", "y"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
#ax.set_xticklabels(rotation= 90)
ax.set(title= "ExGR Zero Accuracy")
# Out:
# D:\Users\Owner\Anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
OD = pd.read_csv("Oat_Data.csv")

# %%
OD
# Out:
#      Plot  Date_Index        Date Variety   Cover  Mean_Green  EXG_Mean_Image  \
# 0    101A    20210708    7/8/2021     Oat  Fallow  117.757186        0.037808
# 1    101B    20210708    7/8/2021     Oat    Post  116.859150        0.029749
# 2    101C    20210708    7/8/2021     Oat   Under  117.632568        0.036861
# 3    102A    20210708    7/8/2021     Oat  Fallow  119.025312        0.024950
# 4    102B    20210708    7/8/2021     Oat    Post  116.398118        0.031162
# ..    ...         ...         ...     ...     ...         ...             ...
# 835  409B    20211025  10/25/2021     Oat  Fallow  106.900187       -0.025017
# 836  409C    20211025  10/25/2021     Oat    Post  105.746490        0.210126
# 837  410A    20211025  10/25/2021     Oat   Under  112.495750        0.460969
# 838  410B    20211025  10/25/2021     Oat  Fallow  110.224567        0.008785
# 839  410C    20211025  10/25/2021     Oat    Post  107.687507        0.167891
#
# ...

# %%
OD.Date=pd.to_datetime(OD.Date, format="%m/%d/%Y")

# %%
test = OD.Date -OD.Date.min()

# %%
test
# Out:
# 0       0 days
# 1       0 days
# 2       0 days
# 3       0 days
# 4       0 days
#         ...
# 835   109 days
# 836   109 days
# 837   109 days
# 838   109 days
# 839   109 days
# Name: Date, Length: 840, dtype: timedelta64[ns]

# %%
OD["Days"] = test

# %%
OD["Days"]= OD["Days"].dt.days

# %%
sns.set_theme(style ="whitegrid")

ax1 = sns.lineplot(data = OD, x="Days", y="Vegetation_Fraction",   
                   hue="Cover", palette = ["r", "b", "g"], style = "Cover", markers = True)
#ax1.set(xticks=ticks)
#ax1.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"])
#ax1.set_ylabels("Vegetation Cover")
ax1.set(xlabel = "Date", ylabel = "Vegetation Cover",  
        ylim=(0,1.1), xlim=(-10, 120), 
        yticklabels = (["0%", "20%", "40%", "60%", "80%", "100%"]))
ax1.set_xticklabels(labels = ["6/18", "7/8", "7/28", "8/17", "9/6", "9/26", "10/16", "11/5"], rotation= 90)
ax1.axvline(29, color='dimgrey', ls = "--", label = "Harvest")
ax1.axvline(35, color='dimgrey', ls = ":", label = "Post Seed")
ax1.set_title("Percent Vegetation", size = 20)
ax1.legend(bbox_to_anchor=(1,1))

#ax1.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_21724\2310190955.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set(xlabel = "Date", ylabel = "Vegetation Cover",
# C:\Users\Owner\AppData\Local\Temp\ipykernel_21724\2310190955.py:11: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels = ["6/18", "7/8", "7/28", "8/17", "9/6", "9/26", "10/16", "11/5"], rotation= 90)

# %%
ND = pd.read_excel("Oat-Clover_Plot_Map_and_Datasheet.xlsx")

# %%
ND
# Out:
#           Study    Lab    year  plot row  column  block variety population  \
# 0    Oat-Clover  Ewing  2021.0  101A   A   101.0    1.0   Reins        Med
# 1    Oat-Clover  Ewing  2021.0  101B   B   101.0    1.0   Reins        Med
# 2    Oat-Clover  Ewing  2021.0  101C   C   101.0    1.0   Reins        Med
# 3    Oat-Clover  Ewing  2021.0  102A   A   102.0    1.0    Sumo        Low
# 4    Oat-Clover  Ewing  2021.0  102B   B   102.0    1.0    Sumo        Low
# ..          ...    ...     ...   ...  ..     ...    ...     ...        ...
# 115  Oat-Clover  Ewing  2021.0  409B   B   409.0    4.0    Sumo        Med
# 116  Oat-Clover  Ewing  2021.0  409C   C   409.0    4.0    Sumo        Med
# 117  Oat-Clover  Ewing  2021.0  410A   A   410.0    4.0   Natty        Low
# 118  Oat-Clover  Ewing  2021.0  410B   B   410.0    4.0   Natty        Low
# 119  Oat-Clover  Ewing  2021.0  410C   C   410.0    4.0   Natty        Low
#
#       cover  ...  clover_N_fall  clover_c_fall  clover_cn_fall  \
# ...

# %%
ND.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 26 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Study                 120 non-null    object
#  1   Lab                   120 non-null    object
#  2   year                  120 non-null    float64
#  3   plot                  120 non-null    object
#  4   row                   120 non-null    object
#  5   column                120 non-null    float64
#  6   block                 120 non-null    float64
#  7   variety               120 non-null    object
#  8   population            120 non-null    object
#  9   cover                 120 non-null    object
#  10  stand                 120 non-null    float64
#  11  yield                 120 non-null    float64
#  12  clover_fall           120 non-null    float64
#  13  volunteer_fall        120 non-null    float64
# ...

# %%
Harvest = OD[(OD["Date_Index"]== 20211025)].reset_index(0)

# %%
Harvest
# Out:
#      index  Plot  Date_Index       Date Variety   Cover  Mean_Green  \
# 0      720  101A    20211025 2021-10-25     Oat  Fallow  103.346481
# 1      721  101B    20211025 2021-10-25     Oat    Post  112.927345
# 2      722  101C    20211025 2021-10-25     Oat   Under  122.571497
# 3      723  102A    20211025 2021-10-25     Oat  Fallow  102.388747
# 4      724  102B    20211025 2021-10-25     Oat    Post  113.197957
# ..     ...   ...         ...        ...     ...     ...         ...
# 115    835  409B    20211025 2021-10-25     Oat  Fallow  106.900187
# 116    836  409C    20211025 2021-10-25     Oat    Post  105.746490
# 117    837  410A    20211025 2021-10-25     Oat   Under  112.495750
# 118    838  410B    20211025 2021-10-25     Oat  Fallow  110.224567
# 119    839  410C    20211025 2021-10-25     Oat    Post  107.687507
#
#      EXG_Mean_Image  EXG_Local_Thresh  EXG_Global_Thresh  ... EXG_Zero_GBD  \
# ...

# %%
Harvest["Biomass"] = ND["clover_fall_kg_ha"]

# %%
Harvest
# Out:
#      index  Plot  Date_Index       Date Variety   Cover  Mean_Green  \
# 0      720  101A    20211025 2021-10-25     Oat  Fallow  103.346481
# 1      721  101B    20211025 2021-10-25     Oat    Post  112.927345
# 2      722  101C    20211025 2021-10-25     Oat   Under  122.571497
# 3      723  102A    20211025 2021-10-25     Oat  Fallow  102.388747
# 4      724  102B    20211025 2021-10-25     Oat    Post  113.197957
# ..     ...   ...         ...        ...     ...     ...         ...
# 115    835  409B    20211025 2021-10-25     Oat  Fallow  106.900187
# 116    836  409C    20211025 2021-10-25     Oat    Post  105.746490
# 117    837  410A    20211025 2021-10-25     Oat   Under  112.495750
# 118    838  410B    20211025 2021-10-25     Oat  Fallow  110.224567
# 119    839  410C    20211025 2021-10-25     Oat    Post  107.687507
#
#      EXG_Mean_Image  EXG_Local_Thresh  EXG_Global_Thresh  ... EXGR_Zero_GBD  \
# ...

# %%
Harvest["Nitrogen"]=ND["clover_N_fall"]

# %%
Harvest["Carbon_Nitrogen"] = ND["clover_cn_fall"]

# %%
Harvest
# Out:
#      index  Plot  Date_Index       Date Variety   Cover  Mean_Green  \
# 0      720  101A    20211025 2021-10-25     Oat  Fallow  103.346481
# 1      721  101B    20211025 2021-10-25     Oat    Post  112.927345
# 2      722  101C    20211025 2021-10-25     Oat   Under  122.571497
# 3      723  102A    20211025 2021-10-25     Oat  Fallow  102.388747
# 4      724  102B    20211025 2021-10-25     Oat    Post  113.197957
# ..     ...   ...         ...        ...     ...     ...         ...
# 115    835  409B    20211025 2021-10-25     Oat  Fallow  106.900187
# 116    836  409C    20211025 2021-10-25     Oat    Post  105.746490
# 117    837  410A    20211025 2021-10-25     Oat   Under  112.495750
# 118    838  410B    20211025 2021-10-25     Oat  Fallow  110.224567
# 119    839  410C    20211025 2021-10-25     Oat    Post  107.687507
#
#      EXG_Mean_Image  EXG_Local_Thresh  EXG_Global_Thresh  ... VARI_Zero_GBD  \
# ...

# %%
sns.set_theme(style ="whitegrid")

sns.scatterplot(x = "Vegetation_Fraction", y = "Biomass", data = Harvest, hue = "Cover")
# Out:
# <AxesSubplot:xlabel='Vegetation_Fraction', ylabel='Biomass'>

# %%
sns.scatterplot(x = "Vegetaton_Mean_Green", y = "Nitrogen", data = Harvest, hue = "Cover")
# Out:
# <AxesSubplot:xlabel='Vegetaton_Mean_Green', ylabel='Nitrogen'>

# %%
sns.scatterplot(x = "Vegetaton_Mean_Green", y = "Carbon_Nitrogen", data = Harvest, hue = "Cover")
# Out:
# <AxesSubplot:xlabel='Vegetaton_Mean_Green', ylabel='Carbon_Nitrogen'>

# %%
sns.scatterplot(x = "Vegetation_Mean_EXG", y = "Nitrogen", data = Harvest, hue = "Cover")
# Out:
# <AxesSubplot:xlabel='Vegetation_Mean_EXG', ylabel='Nitrogen'>

# %%
sns.scatterplot(x = "Vegetation_Mean_EXGR", y = "Nitrogen", data = Harvest, hue = "Cover")
# Out:
# <AxesSubplot:xlabel='Vegetation_Mean_EXGR', ylabel='Nitrogen'>

# %%
sns.scatterplot(x = "Vegetation_Mean_EXGR", y = "Carbon_Nitrogen", data = Harvest, hue = "Cover")
# Out:
# <AxesSubplot:xlabel='Vegetation_Mean_EXGR', ylabel='Carbon_Nitrogen'>

# %%
sns.scatterplot(x = "Vegetation_Mean_EXG", y = "Carbon_Nitrogen", data = Harvest, hue = "Cover")
# Out:
# <AxesSubplot:xlabel='Vegetation_Mean_EXG', ylabel='Carbon_Nitrogen'>
