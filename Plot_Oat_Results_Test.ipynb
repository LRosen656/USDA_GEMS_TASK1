# %%
import seaborn as sns
import pandas as pd
import os
import numpy as np
from datetime import datetime , timedelta
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
from matplotlib.dates import DateFormatter
import matplotlib.dates as mdates
from scipy import stats

# %%
if not os.path.exists("./graphs/"):
    os.mkdir("./graphs/")
graph_out = "./graphs/"

# %%
Stats = pd.read_csv("./Image_Stats.csv")

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "EXG_Local_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Excess Green Local Accuracy")

ax.savefig(graph_out + "EXG_LOCAL_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "EXGR_Local_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Excess Green minus Red Local Accuracy")

ax.savefig(graph_out + "EXGR_LOCAL_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "GLI_Local_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Green Leaf Index Local Accuracy")

ax.savefig(graph_out + "GLI_LOCAL_AC", dpi= 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "VARI_Local_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Visible Atmospherically Resistant Index Local Accuracy")

ax.savefig(graph_out + "VARI_LOCAL_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "EXG_Global_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Excess Green Global Accuracy")

ax.savefig(graph_out + "EXG_GLOBAL_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "EXGR_Global_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Excess Green minus Red Global Accuracy")

ax.savefig(graph_out + "EXGR_GLOBAL_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "GLI_Global_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Green Leaf Index Global Accuracy")

ax.savefig(graph_out + "GLI_GLOBAL_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "VARI_Global_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Visible Atmospherically Resistant Index Global Accuracy")

ax.savefig(graph_out + "VARI_GLOBAL_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "EXG_Zero_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Excess Green Zero Accuracy")

ax.savefig(graph_out + "EXG_ZERO_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "EXGR_Zero_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Excess Green minus Red Zero Accuracy")

ax.savefig(graph_out + "EXGR_ZERO_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "GLI_Zero_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Green Leaf Index Zero Accuracy")

ax.savefig(graph_out + "GLI_ZERO_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "VARI_Zero_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Visible Atmospherically Resistant Index Zero Accuracy")

ax.savefig(graph_out + "VARI_ZERO_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
Stats
# Out:
#             Image  Plot  Date_Index        Date Variety   Cover  EXG_Local_AC  \
# 0   302A_20210708  302A    20210708  07/08/2021     Oat    Post      0.333333
# 1   403C_20210708  403C    20210708  07/08/2021     Oat    Post      0.866667
# 2   309C_20210708  309C    20210708  07/08/2021     Oat   Under      0.466667
# 3   207A_20210708  207A    20210708  07/08/2021     Oat   Under      0.200000
# 4   102C_20210708  102C    20210708  07/08/2021     Oat   Under      0.366667
# 5   402C_20210708  402C    20210708  07/08/2021     Oat    Post      0.666667
# 6   206A_20210708  206A    20210708  07/08/2021     Oat   Under      0.466667
# 7   401A_20210708  401A    20210708  07/08/2021     Oat   Under      0.766667
# 8   207A_20210821  207A    20210821  08/21/2021     Oat   Under      0.133333
# 9   301A_20210821  301A    20210821  08/21/2021     Oat    Post      0.833333
# 10  409B_20210821  409B    20210821  08/21/2021     Oat  Fallow      0.866667
# 11  310B_20210821  310B    20210821  08/21/2021     Oat  Fallow      0.200000
# 12  207B_20210821  207B    20210821  08/21/2021     Oat  Fallow      0.733333
# 13  107B_20210821  107B    20210821  08/21/2021     Oat    Post      0.233333
# 14  104B_20210821  104B    20210821  08/21/2021     Oat    Post      0.933333
# 15  407C_20210909  407C    20210909  09/09/2021     Oat    Post      0.166667
# 16  202A_20210909  202A    20210909  09/09/2021     Oat   Under      0.800000
# 17  102A_20210909  102A    20210909  09/09/2021     Oat  Fallow      0.133333
# 18  406B_20210909  406B    20210909  09/09/2021     Oat  Fallow      0.966667
# 19  109C_20210909  109C    20210909  09/09/2021     Oat   Under      0.700000
# 20  403C_20210909  403C    20210909  09/09/2021     Oat    Post      0.066667
# 21  401A_20210929  401A    20210929  09/29/2021     Oat   Under      0.366667
# 22  301B_20210929  301B    20210929  09/29/2021     Oat  Fallow      0.033333
# 23  210C_20210929  210C    20210929  09/29/2021     Oat    Post      0.900000
# 24  308B_20210929  308B    20210929  09/29/2021     Oat  Fallow      0.733333
# 25  308A_20210929  308A    20210929  09/29/2021     Oat    Post      0.900000
# 26  409A_20210929  409A    20210929  09/29/2021     Oat   Under      0.433333
# 27  302C_20210929  302C    20210929  09/29/2021     Oat   Under      0.833333
# 28  205C_20210929  205C    20210929  09/29/2021     Oat    Post      0.900000
# 29  104B_20211005  104B    20211005  10/05/2021     Oat    Post      0.733333
# 30  406B_20211005  406B    20211005  10/05/2021     Oat  Fallow      0.100000
# 31  201B_20210821  201B    20210821  08/21/2021     Oat  Fallow      0.100000
# 32  103B_20211005  103B    20211005  10/05/2021     Oat    Post      0.766667
# 33  401A_20211005  401A    20211005  10/05/2021     Oat   Under      0.200000
# 34  404A_20211005  404A    20211005  10/05/2021     Soy   Under      0.566667
# 35  401B_20211005  401B    20211005  10/05/2021     Oat  Fallow      0.133333
# 36  110B_20211005  110B    20211005  10/05/2021     Oat    Post      0.766667
# 37  109B_20211005  109B    20211005  10/05/2021     Oat    Post      0.700000
# 38  209A_20211015  209A    20211015  10/15/2021     Oat   Under      0.633333
# 39  407B_20211015  407B    20211015  10/15/2021     Oat  Fallow      0.033333
# 40  304A_20211015  304A    20211015  10/15/2021     Oat    Post      0.933333
# 41  301B_20211015  301B    20211015  10/15/2021     Oat  Fallow      0.100000
# 42  202A_20211015  202A    20211015  10/15/2021     Oat   Under      0.500000
# 43  406C_20211015  406C    20211015  10/15/2021     Oat    Post      0.733333
# 44  305A_20211015  305A    20211015  10/15/2021     Oat    Post      0.633333
# 45  209C_20211015  209C    20211015  10/15/2021     Oat    Post      0.766667
# 46  304A_20211025  304A    20211025  10/25/2021     Oat    Post      0.700000
# 47  406A_20211025  406A    20211025  10/25/2021     Oat   Under      0.400000
# 48  202A_20211025  202A    20211025  10/25/2021     Oat   Under      0.400000
# 49  308C_20211025  308C    20211025  10/25/2021     Oat   Under      0.633333
# 50  306C_20211025  306C    20211025  10/25/2021     Oat   Under      0.233333
# 51  202C_20211025  202C    20211025  10/25/2021     Oat    Post      0.800000
# 52  309B_20211025  309B    20211025  10/25/2021     Oat  Fallow      0.233333
# 53  101C_20211025  101C    20211025  10/25/2021     Oat   Under      0.366667
# 54  103B_20210909  103B    20210909  09/09/2021     Oat    Post      0.166667
# 55  103C_20210909  103C    20210909  09/09/2021     Oat   Under      0.933333
#
#     EXG_Local_PR  EXG_Local_RC  EXGR_Local_AC  ...  VARI_Zero_RC  ALL_Mode_AC  \
# 0       0.333333      1.000000       0.333333  ...      0.300000     0.633333
# 1       0.857143      0.666667       0.333333  ...      0.555556     0.833333
# 2       0.407407      1.000000       0.466667  ...      0.545455     0.666667
# 3       0.142857      1.000000       0.200000  ...      0.500000     0.733333
# 4       0.333333      0.900000       0.366667  ...      0.200000     0.600000
# 5       0.916667      0.550000       0.833333  ...      0.900000     0.800000
# 6       0.448276      1.000000       0.466667  ...      0.307692     0.666667
# 7       0.500000      0.428571       0.233333  ...      0.285714     0.733333
# 8       0.071429      1.000000       0.133333  ...      1.000000     0.766667
# 9       0.000000      0.000000       0.133333  ...      1.000000     0.666667
# 10      0.555556      1.000000       0.200000  ...      0.800000     0.866667
# 11      0.206897      0.857143       0.200000  ...      0.714286     0.833333
# 12      0.333333      0.600000       0.166667  ...      0.800000     0.700000
# 13      0.233333      1.000000       0.233333  ...      0.857143     0.766667
# 14      0.000000      0.000000       0.100000  ...      1.000000     0.633333
# 15      0.137931      1.000000       0.166667  ...      0.500000     0.433333
# 16      0.928571      0.722222       0.800000  ...      1.000000     0.833333
# 17      0.103448      1.000000       0.166667  ...      0.000000     0.633333
# 18      1.000000      0.800000       0.233333  ...      1.000000     0.833333
# 19      1.000000      0.307692       0.733333  ...      0.923077     0.900000
# 20      0.034483      1.000000       0.066667  ...      1.000000     0.600000
# 21      1.000000      0.240000       0.800000  ...      1.000000     0.900000
# 22      0.033333      1.000000       0.033333  ...      1.000000     0.333333
# 23      0.500000      0.333333       0.900000  ...      1.000000     0.933333
# 24      0.000000      0.000000       0.033333  ...      1.000000     0.733333
# 25      0.857143      0.750000       0.933333  ...      1.000000     0.966667
# 26      1.000000      0.291667       0.466667  ...      1.000000     0.900000
# 27      0.857143      0.900000       0.866667  ...      0.950000     0.866667
# 28      0.800000      0.666667       0.900000  ...      1.000000     0.933333
# 29      0.600000      0.333333       0.766667  ...      0.777778     0.733333
# 30      0.035714      1.000000       0.133333  ...      1.000000     0.533333
# 31      0.068966      1.000000       0.100000  ...      0.500000     0.966667
# 32      1.000000      0.363636       0.866667  ...      0.909091     0.933333
# 33      0.750000      0.115385       0.200000  ...      1.000000     0.666667
# 34      0.833333      0.294118       0.566667  ...      1.000000     0.700000
# 35      0.103448      1.000000       0.133333  ...      0.333333     0.600000
# 36      0.666667      0.444444       0.800000  ...      0.888889     0.700000
# 37      0.750000      0.461538       0.700000  ...      0.923077     0.900000
# 38      0.875000      0.411765       0.700000  ...      1.000000     0.800000
# 39      0.033333      1.000000       0.033333  ...      1.000000     0.533333
# 40      1.000000      0.882353       0.966667  ...      1.000000     0.933333
# 41      0.100000      1.000000       0.100000  ...      0.333333     0.733333
# 42      1.000000      0.318182       0.333333  ...      1.000000     0.766667
# 43      1.000000      0.111111       0.833333  ...      1.000000     0.800000
# 44      0.714286      0.357143       0.666667  ...      0.928571     0.866667
# 45      1.000000      0.363636       0.833333  ...      1.000000     0.766667
# 46      1.000000      0.181818       0.433333  ...      1.000000     0.766667
# 47      0.833333      0.227273       0.300000  ...      1.000000     0.700000
# 48      0.750000      0.272727       0.333333  ...      1.000000     0.700000
# 49      1.000000      0.214286       0.600000  ...      1.000000     0.800000
# 50      0.000000      0.000000       0.266667  ...      1.000000     0.833333
# 51      0.625000      0.625000       0.800000  ...      1.000000     0.766667
# 52      0.115385      1.000000       0.200000  ...      0.666667     0.533333
# 53      0.500000      0.105263       0.400000  ...      0.947368     0.733333
# 54      0.107143      1.000000       0.133333  ...      1.000000     0.466667
# 55      0.714286      1.000000       0.933333  ...      1.000000     0.900000
#
#     ALL_Mode_PR  ALL_Mode_RC  ZERO_Mode_AC  ZERO_Mode_PR  ZERO_Mode_RC  \
# 0      0.470588     0.800000      0.733333      0.750000      0.300000
# 1      0.750000     0.666667      0.800000      0.714286      0.555556
# 2      0.533333     0.727273      0.833333      0.875000      0.636364
# 3      0.333333     1.000000      0.900000      0.666667      0.500000
# 4      0.428571     0.600000      0.633333      0.400000      0.200000
# 5      0.937500     0.750000      0.833333      0.857143      0.900000
# 6      0.578947     0.846154      0.666667      0.800000      0.307692
# 7      0.428571     0.428571      0.800000      0.666667      0.285714
# 8      0.222222     1.000000      0.900000      0.400000      1.000000
# 9      0.285714     1.000000      0.666667      0.285714      1.000000
# 10     0.555556     1.000000      0.866667      0.555556      1.000000
# 11     0.625000     0.714286      0.866667      0.714286      0.714286
# 12     0.333333     0.800000      0.700000      0.333333      0.800000
# 13     0.500000     0.714286      0.866667      0.714286      0.714286
# 14     0.153846     1.000000      0.633333      0.153846      1.000000
# 15     0.117647     0.500000      0.766667      0.285714      0.500000
# 16     0.809524     0.944444      0.766667      0.720000      1.000000
# 17     0.214286     1.000000      0.766667      0.000000      0.000000
# 18     0.500000     1.000000      0.833333      0.500000      1.000000
# 19     0.916667     0.846154      0.666667      0.571429      0.923077
# 20     0.076923     1.000000      0.866667      0.200000      1.000000
# 21     0.958333     0.920000      0.866667      0.862069      1.000000
# 22     0.047619     1.000000      0.766667      0.125000      1.000000
# 23     0.666667     0.666667      0.833333      0.375000      1.000000
# 24     0.111111     1.000000      0.833333      0.166667      1.000000
# 25     0.888889     1.000000      0.900000      0.727273      1.000000
# 26     0.956522     0.916667      0.966667      0.960000      1.000000
# 27     0.863636     0.950000      0.833333      0.826087      0.950000
# 28     0.750000     1.000000      0.833333      0.545455      1.000000
# 29     0.545455     0.666667      0.666667      0.466667      0.777778
# 30     0.066667     1.000000      0.833333      0.166667      1.000000
# 31     1.000000     0.500000      0.966667      1.000000      0.500000
# 32     0.909091     0.909091      0.800000      0.666667      0.909091
# 33     0.833333     0.769231      0.866667      0.866667      1.000000
# 34     0.750000     0.705882      0.833333      0.772727      1.000000
# 35     0.153846     0.666667      0.766667      0.166667      0.333333
# 36     0.500000     0.777778      0.600000      0.421053      0.888889
# 37     0.857143     0.923077      0.833333      0.750000      0.923077
# 38     0.823529     0.823529      0.866667      0.809524      1.000000
# 39     0.066667     1.000000      0.800000      0.142857      1.000000
# 40     0.894737     1.000000      0.900000      0.850000      1.000000
# 41     0.272727     1.000000      0.800000      0.200000      0.333333
# 42     0.777778     0.954545      0.766667      0.758621      1.000000
# 43     0.600000     1.000000      0.733333      0.529412      1.000000
# 44     0.857143     0.857143      0.866667      0.812500      0.928571
# 45     0.611111     1.000000      0.666667      0.523810      1.000000
# 46     0.611111     1.000000      0.766667      0.611111      1.000000
# 47     0.842105     0.727273      0.833333      0.814815      1.000000
# 48     0.724138     0.954545      0.733333      0.733333      1.000000
# 49     0.722222     0.928571      0.766667      0.666667      1.000000
# 50     0.840000     0.954545      0.733333      0.733333      1.000000
# 51     0.533333     1.000000      0.633333      0.421053      1.000000
# 52     0.176471     1.000000      0.800000      0.285714      0.666667
# 53     0.739130     0.894737      0.600000      0.620690      0.947368
# 54     0.157895     1.000000      0.900000      0.500000      1.000000
# 55     0.625000     1.000000      0.700000      0.357143      1.000000
#
#     GLOBAL_ZERO_Mode_AC  GLOBAL_ZERO_Mode_PR  GLOBAL_ZERO_Mode_RC
# 0              0.733333             0.750000             0.300000
# 1              0.800000             1.000000             0.333333
# 2              0.800000             0.857143             0.545455
# 3              0.866667             0.500000             0.250000
# 4              0.666667             0.500000             0.100000
# 5              0.800000             0.937500             0.750000
# 6              0.700000             1.000000             0.307692
# 7              0.800000             1.000000             0.142857
# 8              0.933333             0.500000             1.000000
# 9              0.933333             0.666667             1.000000
# 10             0.900000             0.625000             1.000000
# 11             0.900000             0.833333             0.714286
# 12             0.733333             0.333333             0.600000
# 13             0.833333             1.000000             0.285714
# 14             0.866667             0.250000             0.500000
# 15             0.900000             0.666667             0.500000
# 16             0.800000             0.772727             0.944444
# 17             0.766667             0.000000             0.000000
# 18             0.866667             0.555556             1.000000
# 19             0.900000             0.916667             0.846154
# 20             0.966667             0.500000             1.000000
# 21             0.933333             0.925926             1.000000
# 22             0.966667             0.500000             1.000000
# 23             0.933333             0.666667             0.666667
# 24             0.933333             0.000000             0.000000
# 25             0.966667             0.888889             1.000000
# 26             0.966667             0.960000             1.000000
# 27             0.866667             0.863636             0.950000
# 28             0.933333             0.750000             1.000000
# 29             0.733333             0.545455             0.666667
# 30             0.933333             0.333333             1.000000
# 31             0.966667             1.000000             0.500000
# 32             0.933333             0.909091             0.909091
# 33             0.866667             0.866667             1.000000
# 34             0.833333             0.800000             0.941176
# 35             0.933333             1.000000             0.333333
# 36             0.700000             0.500000             0.777778
# 37             0.900000             0.857143             0.923077
# 38             0.833333             0.800000             0.941176
# 39             0.966667             0.500000             1.000000
# 40             0.933333             0.894737             1.000000
# 41             0.866667             0.333333             0.333333
# 42             0.766667             0.777778             0.954545
# 43             0.800000             0.600000             1.000000
# 44             0.866667             0.857143             0.857143
# 45             0.766667             0.611111             1.000000
# 46             0.800000             0.692308             0.818182
# 47             0.700000             0.782609             0.818182
# 48             0.733333             0.733333             1.000000
# 49             0.833333             0.736842             1.000000
# 50             0.766667             0.758621             1.000000
# 51             0.766667             0.533333             1.000000
# 52             0.866667             0.400000             0.666667
# 53             0.633333             0.653846             0.894737
# 54             1.000000             1.000000             1.000000
# 55             0.900000             0.625000             1.000000
#
# [56 rows x 51 columns]

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "ALL_Mode_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Mode Accuracy")

ax.savefig(graph_out + "Mode_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "ZERO_Mode_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Zero Mode Accuracy")

ax.savefig(graph_out + "Zero_Mode_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
sns.set_theme(style ="whitegrid")


ax = sns.catplot(x = "Date", y = "GLOBAL_ZERO_Mode_AC",  hue="Cover", markers = ["x", "s", "o"], 
                 data = Stats, palette = ["b", "g", "r"], kind = "point",  capsize = .2, dodge  = True, join = False)
ax.set_ylabels("Accuracy")
ax.set(ylim=(0,1))
ax.axes.flat[0].yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1))
ax.set_xticklabels(["7/8", "8/21", "9/9", "9/29", "10/5", "10/15", "10/25"], rotation= 90)
ax.set(title= "Global-Zero Mode Accuracy")

ax.savefig(graph_out + "Global_Zero_Mode_AC", dpi = 300)
# Out:
# C:\Users\Owner\anaconda3\envs\ag_env\lib\site-packages\seaborn\categorical.py:1781: UserWarning: You passed a edgecolor/edgecolors ((0.2980392156862745, 0.4470588235294118, 0.6901960784313725)) for an unfilled marker ('x').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   ax.scatter(x, y, label=hue_level,

# %%
Ground_Truth = pd.read_csv("./Ground_Truth.csv")

# %%
Ground_Truth
# Out:
#               Image  Plot       X       Y  Date_Index        Date Variety  \
# 0     302A_20210708  302A  1162.0   330.0    20210708  07/08/2021     Oat
# 1     302A_20210708  302A   659.0   277.0    20210708  07/08/2021     Oat
# 2     302A_20210708  302A  1255.0    34.0    20210708  07/08/2021     Oat
# 3     302A_20210708  302A   757.0  1186.0    20210708  07/08/2021     Oat
# 4     302A_20210708  302A  1258.0   337.0    20210708  07/08/2021     Oat
# ...             ...   ...     ...     ...         ...         ...     ...
# 1675  103C_20210909  103C  1100.0  1234.0    20210909  09/09/2021     Oat
# 1676  103C_20210909  103C  1049.0   419.0    20210909  09/09/2021     Oat
# 1677  103C_20210909  103C   354.0   168.0    20210909  09/09/2021     Oat
# 1678  103C_20210909  103C   706.0   970.0    20210909  09/09/2021     Oat
# 1679  103C_20210909  103C   180.0   473.0    20210909  09/09/2021     Oat
#
#       Cover  Reference  Predicted_EXG_L  ...  Predicted_ALL_MODE  \
# 0      Post          1                1  ...                   1
# 1      Post          0                1  ...                   1
# 2      Post          1                1  ...                   1
# 3      Post          0                1  ...                   1
# 4      Post          1                1  ...                   1
# ...     ...        ...              ...  ...                 ...
# 1675  Under          0                0  ...                   0
# 1676  Under          0                0  ...                   0
# 1677  Under          0                0  ...                   0
# 1678  Under          1                1  ...                   1
# 1679  Under          1                1  ...                   1
#
#       Predicted_ZERO_MODE  Predicted_GLOBAL_ZERO_MODE  EXG_Value  EXGR_Value  \
# 0                       0                           0   0.044479   -0.096933
# 1                       0                           0   0.035000   -0.113500
# 2                       0                           0   0.171004   -0.031970
# 3                       1                           1   0.197719    0.022053
# 4                       1                           1   0.143750    0.004375
# ...                   ...                         ...        ...         ...
# 1675                    1                           0   0.076923   -0.058689
# 1676                    0                           0   0.071429   -0.071429
# 1677                    0                           0   0.053371   -0.096910
# 1678                    1                           1   0.267380    0.278075
# 1679                    1                           1   0.248869    0.183710
#
#       GLI_Value  VARI_Value  Red_Value  Green_Value  Blue_Value
# 0      0.032992   -0.003876   0.349693     0.348160    0.302147
# 1      0.026022   -0.018987   0.352500     0.345000    0.302500
# 2      0.122995   -0.053254   0.423792     0.390335    0.185874
# 3      0.141304   -0.018405   0.410646     0.399240    0.190114
# 4      0.104072    0.018519   0.371875     0.381250    0.246875
# ...         ...         ...        ...          ...         ...
# 1675   0.056604    0.013423   0.353276     0.358974    0.287749
# 1676   0.052632    0.000000   0.357143     0.357143    0.285714
# 1677   0.039501   -0.016779   0.358146     0.351124    0.290730
# 1678   0.187970    0.296296   0.294118     0.422460    0.283422
# 1679   0.175719    0.139130   0.343891     0.416290    0.239819
#
# [1680 rows x 31 columns]

# %%
sns.set_theme(style = "ticks")
ax = sns.jointplot(x = "Red_Value", y = "Green_Value", data = Ground_Truth, 
                hue = "Reference")
ax.ax_joint.legend_._visible= False
ax.set_axis_labels("Red", "Green" )
#ax.fig.suptitle("Color Spectrum")
ax.fig.legend(labels = ["Vegetation", "Nonvegetation"])

ax.savefig(graph_out+ "Reference_Color", bbox_inches = "tight", dpi = 300)

# %%
ax = sns.jointplot(x = "EXG_Value", y = "Green_Value", data = Ground_Truth, 
                hue = "Reference")
ax.ax_joint.legend_._visible= False
ax.set_axis_labels("Excess Green", "Green")
ax.fig.legend(labels = ["Vegetation", "Nonvegetation"])
ax.savefig(graph_out + "Reference_EXG", bbox_inches = "tight", dpi = 300)

# %%
ax = sns.jointplot(x = "EXGR_Value", y = "Green_Value", data = Ground_Truth, 
                hue = "Reference")
ax.ax_joint.legend_._visible= False
ax.fig.legend(labels = ["Vegegetation", "Nonvegetation"])
ax.set_axis_labels("Excess Green minus Red", "Green")

ax.savefig(graph_out + "Reference_EXGR", bbox_inches = "tight", dpi = 300)

# %%
ax = sns.jointplot(x = "GLI_Value", y = "Green_Value", data = Ground_Truth, 
                hue = "Reference")
ax.ax_joint.legend_._visible= False
ax.fig.legend(labels = ["Vegetation", "Nonvegetation"])
ax.set_axis_labels("Green Leaf Index", "Green")

ax.savefig(graph_out + "Reference_GLI", bbox_inches = "tight", dpi = 300)

# %%
ax = sns.jointplot(x = "VARI_Value", y = "Green_Value", data = Ground_Truth, 
                hue = "Reference")
ax.ax_joint.legend_._visible= False
ax.fig.legend(labels = ["Vegetation", "Nonvegetation"])
ax.set_axis_labels( "Visible Atmospherically Resistant Index", "Green")

ax.savefig(graph_out + "Reference_VARI", bbox_inches = "tight", dpi = 300)

# %%
Oat_Data = pd.read_csv("Oat_Data.csv")

# %%
Oat_Data.Date=pd.to_datetime(Oat_Data.Date, format="%m/%d/%Y")

# %%
Days = Oat_Data.Date -Oat_Data.Date.min()  #Date 7/8 will be 0

# %%
Oat_Data["Days"] = Days.dt.days ##Days as integer

# %%
sns.set_theme(style ="whitegrid")

ax = sns.lineplot(data = Oat_Data, x="Days", y="Vegetation_Fraction",   
                   hue="Cover", palette = ["r", "b", "g"], style = "Cover", markers = True)  

ax.set(xlabel = "Date", ylabel = "Vegetation Cover",  
        ylim=(0,1.1), xlim=(-5, 115), 
        yticklabels = (["0%", "20%", "40%", "60%", "80%", "100%"]),  ##Y labels
       title = "Percent Vegetation") 
ax.set_xticklabels(labels = ["7/3", "7/8", "7/28", "8/17", "9/6", "9/26", "10/16", "10/31"], rotation= 90) #first date not shown 
ax.axvline(29, color='dimgrey', ls = "--", label = "Crop Harvest")
ax.axvline(35, color='dimgrey', ls = ":", label = "Post Plant")
ax.legend(bbox_to_anchor=(1,1))

plt.savefig(graph_out + "Percent_Vegetation", bbox_inches = "tight", dpi = 300)
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_35596\3511810389.py:6: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set(xlabel = "Date", ylabel = "Vegetation Cover",
# C:\Users\Owner\AppData\Local\Temp\ipykernel_35596\3511810389.py:10: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(labels = ["7/3", "7/8", "7/28", "8/17", "9/6", "9/26", "10/16", "10/31"], rotation= 90) #first date not shown

# %%
Bio_Data = pd.read_excel("Oat-Clover_Plot_Map_and_Datasheet.xlsx")

# %%
Harvest = Oat_Data[(Oat_Data["Date_Index"]== 20211025)].reset_index(drop = True)  ##Separates the last date.

# %%
Harvest
# Out:
#              Image  Plot  Date_Index       Date Variety   Cover  Green_Avg  \
# 0    101A_20211025  101A    20211025 2021-10-25     Oat  Fallow   0.340791
# 1    101B_20211025  101B    20211025 2021-10-25     Oat    Post   0.398933
# 2    101C_20211025  101C    20211025 2021-10-25     Oat   Under   0.469053
# 3    102A_20211025  102A    20211025 2021-10-25     Oat  Fallow   0.321901
# 4    102B_20211025  102B    20211025 2021-10-25     Oat    Post   0.366825
# ..             ...   ...         ...        ...     ...     ...        ...
# 115  409B_20211025  409B    20211025 2021-10-25     Oat  Fallow   0.324957
# 116  409C_20211025  409C    20211025 2021-10-25     Oat    Post   0.403345
# 117  410A_20211025  410A    20211025 2021-10-25     Oat   Under   0.486970
# 118  410B_20211025  410B    20211025 2021-10-25     Oat  Fallow   0.336206
# 119  410C_20211025  410C    20211025 2021-10-25     Oat    Post   0.389259
#
#      EXG_Avg_Image  EXGR_Avg_Image  GLI_Avg_Image  ...  EXGR_Global_Thresh  \
# 0         0.022484       -0.188345       0.004368  ...            0.205078
# 1         0.196890        0.083133       0.123418  ...            0.205078
# 2         0.407197        0.413225       0.261080  ...            0.205078
# 3        -0.034138       -0.291791      -0.038801  ...            0.205078
# 4         0.100571       -0.089723       0.057934  ...            0.205078
# ..             ...             ...            ...  ...                 ...
# 115      -0.025017       -0.260596      -0.029944  ...            0.205078
# 116       0.210126        0.108752       0.131284  ...            0.205078
# 117       0.460969        0.502542       0.290155  ...            0.205078
# 118       0.008785       -0.204253      -0.007075  ...            0.205078
# 119       0.167891        0.038922       0.101466  ...            0.205078
#
#      GLI_Global_Thresh  VARI_Global_Thresh  Vegetation_Fraction  \
# 0             0.160156           -0.089844             0.193043
# 1             0.160156           -0.089844             0.515324
# 2             0.160156           -0.089844             0.861217
# 3             0.160156           -0.089844             0.087225
# 4             0.160156           -0.089844             0.330060
# ..                 ...                 ...                  ...
# 115           0.160156           -0.089844             0.101028
# 116           0.160156           -0.089844             0.542867
# 117           0.160156           -0.089844             0.875943
# 118           0.160156           -0.089844             0.165693
# 119           0.160156           -0.089844             0.469610
#
#      Green_Avg_Vegetation  EXG_Avg_Vegetation  EXGR_Avg_Vegetation  \
# 0                0.435801            0.307403             0.274478
# 1                0.464835            0.394505             0.395593
# 2                0.489601            0.468803             0.511404
# 3                0.439954            0.319862             0.302392
# 4                0.454432            0.363296             0.338523
# ..                    ...                 ...                  ...
# 115              0.427930            0.283790             0.266255
# 116              0.468458            0.405373             0.420653
# 117              0.508097            0.524291             0.604697
# 118              0.444000            0.332001             0.325336
# 119              0.466305            0.398916             0.408859
#
#      GLI_Avg_Vegetation  VARI_Avg_Vegetation  Days
# 0              0.202781             0.170827   109
# 1              0.255770             0.203921   109
# 2              0.301195             0.254713   109
# 3              0.206491             0.192812   109
# 4              0.238310             0.173894   109
# ..                  ...                  ...   ...
# 115            0.186371             0.212816   109
# 116            0.262521             0.229079   109
# 117            0.330985             0.298510   109
# 118            0.215333             0.212896   109
# 119            0.257941             0.219866   109
#
# [120 rows x 26 columns]

# %%
Harvest["Biomass"] = Bio_Data["clover_fall_kg_ha"]  ##Biomass (kg/ha)

# %%
Harvest["Nitrogen"]= Bio_Data["clover_N_fall"] ##Nitrogen (percent by mass)

# %%
Harvest["Carbon_Nitrogen"] = Bio_Data["clover_cn_fall"] ##Carbon-Nitrogen Ratio

# %%
Harvest
# Out:
#              Image  Plot  Date_Index       Date Variety   Cover  Green_Avg  \
# 0    101A_20211025  101A    20211025 2021-10-25     Oat  Fallow   0.340791
# 1    101B_20211025  101B    20211025 2021-10-25     Oat    Post   0.398933
# 2    101C_20211025  101C    20211025 2021-10-25     Oat   Under   0.469053
# 3    102A_20211025  102A    20211025 2021-10-25     Oat  Fallow   0.321901
# 4    102B_20211025  102B    20211025 2021-10-25     Oat    Post   0.366825
# ..             ...   ...         ...        ...     ...     ...        ...
# 115  409B_20211025  409B    20211025 2021-10-25     Oat  Fallow   0.324957
# 116  409C_20211025  409C    20211025 2021-10-25     Oat    Post   0.403345
# 117  410A_20211025  410A    20211025 2021-10-25     Oat   Under   0.486970
# 118  410B_20211025  410B    20211025 2021-10-25     Oat  Fallow   0.336206
# 119  410C_20211025  410C    20211025 2021-10-25     Oat    Post   0.389259
#
#      EXG_Avg_Image  EXGR_Avg_Image  GLI_Avg_Image  ...  Vegetation_Fraction  \
# 0         0.022484       -0.188345       0.004368  ...             0.193043
# 1         0.196890        0.083133       0.123418  ...             0.515324
# 2         0.407197        0.413225       0.261080  ...             0.861217
# 3        -0.034138       -0.291791      -0.038801  ...             0.087225
# 4         0.100571       -0.089723       0.057934  ...             0.330060
# ..             ...             ...            ...  ...                  ...
# 115      -0.025017       -0.260596      -0.029944  ...             0.101028
# 116       0.210126        0.108752       0.131284  ...             0.542867
# 117       0.460969        0.502542       0.290155  ...             0.875943
# 118       0.008785       -0.204253      -0.007075  ...             0.165693
# 119       0.167891        0.038922       0.101466  ...             0.469610
#
#      Green_Avg_Vegetation  EXG_Avg_Vegetation  EXGR_Avg_Vegetation  \
# 0                0.435801            0.307403             0.274478
# 1                0.464835            0.394505             0.395593
# 2                0.489601            0.468803             0.511404
# 3                0.439954            0.319862             0.302392
# 4                0.454432            0.363296             0.338523
# ..                    ...                 ...                  ...
# 115              0.427930            0.283790             0.266255
# 116              0.468458            0.405373             0.420653
# 117              0.508097            0.524291             0.604697
# 118              0.444000            0.332001             0.325336
# 119              0.466305            0.398916             0.408859
#
#      GLI_Avg_Vegetation  VARI_Avg_Vegetation  Days     Biomass  Nitrogen  \
# 0              0.202781             0.170827   109    0.000000       NaN
# 1              0.255770             0.203921   109  135.036087    4.6815
# 2              0.301195             0.254713   109  701.976108    3.1371
# 3              0.206491             0.192812   109    0.000000       NaN
# 4              0.238310             0.173894   109  222.386454    4.0756
# ..                  ...                  ...   ...         ...       ...
# 115            0.186371             0.212816   109    0.000000       NaN
# 116            0.262521             0.229079   109  182.809951    3.6463
# 117            0.330985             0.298510   109  976.631753    3.1714
# 118            0.215333             0.212896   109    0.000000       NaN
# 119            0.257941             0.219866   109  159.275594    3.7205
#
#      Carbon_Nitrogen
# 0                NaN
# 1           9.518744
# 2          14.062670
# 3                NaN
# 4          10.506920
# ..               ...
# 115              NaN
# 116        11.697610
# 117        13.706560
# 118              NaN
# 119        11.412440
#
# [120 rows x 29 columns]

# %%
Harvest = Harvest[(Harvest["Cover"]!="Fallow")]

# %%
line = sns.regplot(x = "Vegetation_Fraction", y = "Biomass", data = Harvest, scatter = False, color = "lightgrey")
line.set(ylim = (0, 1400))
line.text(.98, 1400, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["Vegetation_Fraction"],Harvest["Biomass"])[0]**2))
ax = sns.scatterplot(x = "Vegetation_Fraction", y = "Biomass", data = Harvest, 
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Vegetation Fraction", ylabel = "Biomass (kg/ha)",
       title = "Biomass vs Vegetation Cover")
ax.legend(bbox_to_anchor=(1,1))

plt.savefig(graph_out + "Biomass_VC", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "Green_Avg_Vegetation", y = "Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.53, 5.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["Green_Avg_Vegetation"],Harvest["Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "Green_Avg_Vegetation", y = "Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average Green", ylabel = "Nitrogen",
       xlim = (0.44, 0.53), ylim = (0, 5),
       title = "Nitrogen vs Greenness")
ax.legend(bbox_to_anchor=(1.24,1))

plt.savefig(graph_out + "Nitrogen_Greenness", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "EXG_Avg_Vegetation", y = "Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.6, 5.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["EXG_Avg_Vegetation"],Harvest["Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "EXG_Avg_Vegetation", y = "Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average ExG", ylabel = "Nitrogen",
       xlim = (0.33, 0.6), ylim= (0,5),
       title = "Nitrogen vs Excess Green")
ax.legend(bbox_to_anchor=(1.24,1))

plt.savefig(graph_out + "Nitrogen_EXG", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "EXGR_Avg_Vegetation", y = "Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.72, 5.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["EXGR_Avg_Vegetation"],Harvest["Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "EXGR_Avg_Vegetation", y = "Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average ExGR", ylabel = "Nitrogen",
       xlim = (0.33, 0.72), ylim = (0,5),
       title = "Nitrogen vs Excess Green minus Red")
ax.legend(bbox_to_anchor=(1.24,1))

plt.savefig(graph_out + "Nitrogen_EXGR", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "GLI_Avg_Vegetation", y = "Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.386, 5.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["GLI_Avg_Vegetation"],Harvest["Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "GLI_Avg_Vegetation", y = "Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average GLI", ylabel = "Nitrogen",
       xlim = (0.2, 0.38), ylim = (0,5),
       title = "Nitrogen vs Green Leaf Index")
ax.legend(bbox_to_anchor=(1.24,1))

plt.savefig(graph_out + "Nitrogen_GLI", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "VARI_Avg_Vegetation", y = "Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.355, 5.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["VARI_Avg_Vegetation"],Harvest["Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "VARI_Avg_Vegetation", y = "Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average VARI", ylabel = "Nitrogen",
       xlim = (0.15, 0.35), ylim  =(0,5),
       title = "Nitrogen vs Visible Atmospherically Resistant Index")
ax.legend(bbox_to_anchor=(1.24,1))

plt.savefig(graph_out + "Nitrogen_VARI", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "Green_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.53, 18.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["Green_Avg_Vegetation"],Harvest["Carbon_Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "Green_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average Green", ylabel = "Carbon:Nitrogen",
       xlim = (0.44, 0.53), ylim = (0,18),
       title = "Carbon:Nitrogen vs Greenness")
ax.legend(bbox_to_anchor=(1,1))

plt.savefig(graph_out + "CN_Greenness", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "EXG_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.6, 18.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["EXG_Avg_Vegetation"],Harvest["Carbon_Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "EXG_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average ExG", ylabel = "Carbon:Nitrogen",
       xlim = (0.33, 0.6), ylim = (0, 18),
       title = "Carbon:Nitrogen vs Excess Green")
ax.legend(bbox_to_anchor=(1,1))

plt.savefig(graph_out + "CN_EXG", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "EXGR_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.72, 18.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["EXGR_Avg_Vegetation"],Harvest["Carbon_Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "EXGR_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average ExGR", ylabel = "Carbon:Nitrogen",
       xlim = (0.33, 0.72), ylim = (0, 18),
       title = "Carbon:Nitrogen vs Excess Green minus Red")
ax.legend(bbox_to_anchor=(1,1))


plt.savefig(graph_out + "CN_EXGR", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "GLI_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.text(.386, 18.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["GLI_Avg_Vegetation"],Harvest["Carbon_Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "GLI_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average GLI", ylabel = "Carbon:Nitrogen",
       xlim = (0.20, 0.38), ylim = (0, 18),
       title = "Carbon:Nitrogen vs Green Leaf Index")
ax.legend(bbox_to_anchor=(1,1))


plt.savefig(graph_out + "CN_GLI", bbox_inches = "tight", dpi = 300)

# %%
line = sns.regplot(x = "VARI_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest, scatter = False, color = "lightgrey")
line.set(ylim = (0, 1400))
line.text(.355, 18.1, "R-Squared = " + "{:.2f}".format(stats.pearsonr(Harvest["VARI_Avg_Vegetation"],Harvest["Carbon_Nitrogen"])[0]**2))
ax = sns.scatterplot(x = "VARI_Avg_Vegetation", y = "Carbon_Nitrogen", data = Harvest[(Harvest["Cover"]!="Fallow")],
                hue = "Cover", palette=["b", "g"], style = "Cover", markers = ["X", "s"])
ax.set(xlabel = "Average VARI", ylabel = "Carbon:Nitrogen",
       xlim = (0.15, 0.35), ylim = (0, 18),
       title = "Carbon:Nitrogen vs Visible Atmospherically Resistant Index")
ax.legend(bbox_to_anchor=(1,1))

plt.savefig(graph_out + "CN_VARI", bbox_inches = "tight", dpi = 300)
